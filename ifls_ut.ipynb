# %%
import pandas as pd

# %%
df = pd.read_csv('ut2_merge.csv')
df.head()
# Out:
#    Unnamed: 0     id  ut07em_2007  ut07ey_2007  ut07fm_2007  ut07fy_2007  \
# 0           0  20100         10.0       2007.0          5.0       2007.0
# 1           1  20100          4.0       2007.0         11.0       2006.0
# 2           2  20300         10.0       2007.0          7.0       2007.0
# 3           3  20300          5.0       2007.0          2.0       2007.0
# 4           4  20400         12.0       2007.0          7.0       2007.0
#
#    ut07gh_2007  ut07h_2007  ut07i_2007  ut07jh_2007  ...  ut07ey_2014  \
# 0          1.0         1.0         6.0          1.0  ...       2014.0
# 1          1.0         1.0         6.0          1.0  ...       2014.0
# 2          NaN         1.0         6.0          NaN  ...          NaN
# 3          NaN         1.0         6.0          NaN  ...          NaN
# 4          NaN         5.0         6.0          NaN  ...          NaN
#
#    ut07fm_2014  ut07fy_2014 ut07gh_2014  ut07h_2014 ut07i_2014  ut07jh_2014  \
# ...

# %%
ut2_07 = pd.read_stata('2007/b2_ut2.dta')
ut3_07 = pd.read_stata('2007/b2_ut3.dta')
ut2_14 = pd.read_stata('2014/b2_ut2.dta')
ut3_14 = pd.read_stata('2014/b2_ut3.dta')

# %%
ut2_07.head()
# Out:
#   ut2type  ut07ex  ut07emth  ut07eyr  ut07fx  ut07fmth  ut07fyr  ut07gx  \
# 0       A     1.0      10.0   2007.0     1.0       5.0   2007.0     1.0
# 1       B     1.0       4.0   2007.0     1.0      11.0   2006.0     1.0
# 2       A     1.0      10.0   2007.0     1.0       7.0   2007.0     2.0
# 3       B     1.0       5.0   2007.0     1.0       2.0   2007.0     2.0
# 4       A     1.0      12.0   2007.0     1.0       7.0   2007.0     2.0
#
#    ut07gh  ut07h  ...  ut07km  ut07l  ut07m   ut07n     ut07o  ut07p   ut07q  \
# 0     1.0    1.0  ...     NaN  900.0    NaN   800.0  720000.0  360.0  6000.0
# 1     1.0    1.0  ...     NaN  600.0    NaN   800.0  480000.0  240.0  5000.0
# 2     NaN    1.0  ...     NaN   60.0    NaN  3000.0  180000.0   30.0  6000.0
# 3     NaN    1.0  ...     NaN   60.0    NaN  3000.0  180000.0   30.0  6000.0
# 4     NaN    5.0  ...     NaN  120.0    NaN     NaN       NaN   60.0  6000.0
#
#    ut07r  version  module
# 0    NaN      1.0  B2_UT2
# ...

# %%
ut2_07.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3859 entries, 0 to 3858
# Data columns (total 36 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ut2type   3859 non-null   object
#  1   ut07ex    3859 non-null   float64
#  2   ut07emth  3769 non-null   float64
#  3   ut07eyr   3769 non-null   float64
#  4   ut07fx    3859 non-null   float64
#  5   ut07fmth  3826 non-null   float64
#  6   ut07fyr   3826 non-null   float64
#  7   ut07gx    3859 non-null   float64
#  8   ut07gh    1006 non-null   float64
#  9   ut07h     3859 non-null   float64
#  10  ut07i     3859 non-null   float64
#  11  ut07jx    3859 non-null   float64
#  12  ut07jh    972 non-null    float64
#  13  ut07kx    3750 non-null   float64
#  14  ut07kh    151 non-null    float64
#  15  ut07lx    3750 non-null   float64
#  16  ut07lxx   3647 non-null   float64
#  17  ut07mx    275 non-null    float64
#  18  ut07nx    3750 non-null   float64
# ...

# %%
ut3_07.head()
# Out:
#   ut3type  ut09r  ut09sx  ut09sm  ut09sy  ut09tx   hhid07      ut09t  version  \
# 0      C1    3.0     NaN     NaN     NaN     NaN  0012200        NaN      1.0
# 1      C2    3.0     NaN     NaN     NaN     NaN  0012200        NaN      1.0
# 2      C3    3.0     NaN     NaN     NaN     NaN  0012200        NaN      1.0
# 3      C4    1.0     1.0     7.0  2007.0     1.0  0012200  1500000.0      1.0
# 4      C5    3.0     NaN     NaN     NaN     NaN  0012200        NaN      1.0
#
#    module
# 0  B2_UT3
# 1  B2_UT3
# 2  B2_UT3
# 3  B2_UT3
# 4  B2_UT3

# %%
ut3_07.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3005 entries, 0 to 3004
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ut3type  3005 non-null   object
#  1   ut09r    3005 non-null   float64
#  2   ut09sx   621 non-null    float64
#  3   ut09sm   613 non-null    float64
#  4   ut09sy   613 non-null    float64
#  5   ut09tx   621 non-null    float64
#  6   hhid07   3005 non-null   object
#  7   ut09t    582 non-null    float64
#  8   version  3005 non-null   float64
#  9   module   3005 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 258.2+ KB

# %%
ut2_14.head()
# Out:
#          ut07ex       ut07em  ut07ey        ut07fx      ut07fm  ut07fy  \
# 0  1:Given date  11:November  2014.0  1:Given date      7:July  2014.0
# 1  1:Given date  11:November  2014.0  1:Given date       5:May  2014.0
# 2  1:Given date  12:December  2014.0  1:Given date    8:August  2014.0
# 3  1:Given date  9:September  2014.0  1:Given date       5:May  2014.0
# 4  1:Given date   2:February  2015.0  1:Given date  10:October  2014.0
#
#                 ut07gx  ut07gh        ut07h     ut07i  ... ut07km   ut07l  \
# 0  1:Given in hectares    1.00      5:Other  95:Other  ...    NaN   250.0
# 1  1:Given in hectares    0.50       1:Rain  95:Other  ...    NaN   112.0
# 2  1:Given in hectares    0.25       1:Rain    7:IR42  ...    NaN   400.0
# 3  1:Given in hectares    0.25  2:Irigation    6:IR64  ...    NaN  1000.0
# 4  1:Given in hectares    0.50       1:Rain  95:Other  ...    NaN  1200.0
#
#    ut07m   ut07n      ut07o  ut07p    ut07q  ut07r version  module
# ...

# %%
ut2_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2443 entries, 0 to 2442
# Data columns (total 36 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ut07ex   2443 non-null   category
#  1   ut07em   2377 non-null   category
#  2   ut07ey   2377 non-null   category
#  3   ut07fx   2443 non-null   category
#  4   ut07fm   2399 non-null   category
#  5   ut07fy   2399 non-null   category
#  6   ut07gx   2443 non-null   category
#  7   ut07gh   543 non-null    float64
#  8   ut07h    2443 non-null   category
#  9   ut07i    2443 non-null   category
#  10  ut07jx   2443 non-null   category
#  11  ut07jh   539 non-null    float64
#  12  ut07kx   2443 non-null   category
#  13  ut07kh   32 non-null     float64
#  14  ut07lx   2443 non-null   category
#  15  ut07lxx  2343 non-null   category
#  16  ut07mx   465 non-null    category
#  17  ut07nx   2443 non-null   category
#  18  ut07ox   2443 non-null   category
# ...

# %%
ut3_14.head()
# Out:
#   wilcahb2   hhid14_9 ut3type  ut09r   ut09sx    ut09sm  ut09sy   ut09tx  \
# 0      001  001220000      C1   3:No      NaN       NaN     NaN      NaN
# 1      001  001220000      C4   3:No      NaN       NaN     NaN      NaN
# 2      001  001220000      C5   3:No      NaN       NaN     NaN      NaN
# 3      001  001220000      C3  1:Yes  1:Given  8:August  2014.0  1:Given
# 4      001  001220000      C2   3:No      NaN       NaN     NaN      NaN
#
#        idrtk   hhid14      ut09t  version  module
# 0  001220000  0012200        NaN      1.3  B2_UT3
# 1  001220000  0012200        NaN      1.3  B2_UT3
# 2  001220000  0012200        NaN      1.3  B2_UT3
# 3  001220000  0012200  4000000.0      1.3  B2_UT3
# 4  001220000  0012200        NaN      1.3  B2_UT3

# %%
ut2_07_ft = ut2_07[['hhid07','ut07emth','ut07eyr',
                    'ut07fmth','ut07fyr',
                   'ut07gh','ut07h', 'ut07i',
                   'ut07jh','ut07lxx','ut07m',
                   'ut07p']]
ut2_07_ft.head()
# Out:
#     hhid07  ut07emth  ut07eyr  ut07fmth  ut07fyr  ut07gh  ut07h  ut07i  \
# 0  0020100      10.0   2007.0       5.0   2007.0     1.0    1.0    6.0
# 1  0020100       4.0   2007.0      11.0   2006.0     1.0    1.0    6.0
# 2  0020300      10.0   2007.0       7.0   2007.0     NaN    1.0    6.0
# 3  0020300       5.0   2007.0       2.0   2007.0     NaN    1.0    6.0
# 4  0020400      12.0   2007.0       7.0   2007.0     NaN    5.0    6.0
#
#    ut07jh  ut07lxx  ut07m  ut07p
# 0     1.0      1.0    NaN  360.0
# 1     1.0      1.0    NaN  240.0
# 2     NaN      1.0    NaN   30.0
# 3     NaN      1.0    NaN   30.0
# 4     NaN      1.0    NaN   60.0

# %%
ut2_07_ft
# Out:
#        hhid07  ut07emth  ut07eyr  ut07fmth  ut07fyr  ut07gh  ut07h  ut07i  \
# 0     0020100      10.0   2007.0       5.0   2007.0     1.0    1.0    6.0
# 1     0020100       4.0   2007.0      11.0   2006.0     1.0    1.0    6.0
# 2     0020300      10.0   2007.0       7.0   2007.0     NaN    1.0    6.0
# 3     0020300       5.0   2007.0       2.0   2007.0     NaN    1.0    6.0
# 4     0020400      12.0   2007.0       7.0   2007.0     NaN    5.0    6.0
# ...       ...       ...      ...       ...      ...     ...    ...    ...
# 3854  3212741       7.0   2007.0       2.0   2007.0     NaN    1.0   95.0
# 3855  3212900       8.0   2007.0       5.0   2007.0     0.7    1.0   95.0
# 3856  3212900       3.0   2007.0      12.0   2007.0     0.7    1.0   95.0
# 3857  3212911       7.0   2007.0       4.0   2007.0     NaN    1.0   95.0
# 3858  3213000       8.0   2007.0       4.0   2007.0     NaN    1.0   95.0
#
#       ut07jh  ut07lxx  ut07m   ut07p
# 0        1.0      1.0    NaN   360.0
# ...

# %%
ut2_07_clean = ut2_07_ft.dropna()
len(ut2_07_clean)
# Out:
# 29

# %%
ut3_07_ft = ut3_07[['hhid07','ut3type','ut09sm','ut09sy','ut09t']]
ut3_07_ft.head()
# Out:
#     hhid07 ut3type  ut09sm  ut09sy      ut09t
# 0  0012200      C1     NaN     NaN        NaN
# 1  0012200      C2     NaN     NaN        NaN
# 2  0012200      C3     NaN     NaN        NaN
# 3  0012200      C4     7.0  2007.0  1500000.0
# 4  0012200      C5     NaN     NaN        NaN

# %%
ut2_14_ft = ut2_14[['hhid14','ut07em','ut07ey',
                    'ut07fm','ut07fy',
                   'ut07gh','ut07h', 'ut07i',
                   'ut07jh','ut07lxx','ut07m',
                   'ut07p']]
ut2_14_ft.head()
# Out:
#     hhid14       ut07em  ut07ey      ut07fm  ut07fy  ut07gh        ut07h  \
# 0  0020100  11:November  2014.0      7:July  2014.0    1.00      5:Other
# 1  0020600  11:November  2014.0       5:May  2014.0    0.50       1:Rain
# 2  0022000  12:December  2014.0    8:August  2014.0    0.25       1:Rain
# 3  0030100  9:September  2014.0       5:May  2014.0    0.25  2:Irigation
# 4  0030151   2:February  2015.0  10:October  2014.0    0.50       1:Rain
#
#       ut07i  ut07jh             ut07lxx  ut07m  ut07p
# 0  95:Other    1.00  1:Unhusked =>UT07n    NaN  200.0
# 1  95:Other    0.50            2:Husked  140.0   56.0
# 2    7:IR42    0.25  1:Unhusked =>UT07n    NaN  170.0
# 3    6:IR64    0.25  1:Unhusked =>UT07n    NaN  500.0
# 4  95:Other    0.50  1:Unhusked =>UT07n    NaN  480.0

# %%
ut2_14_ft
# Out:
#        hhid14       ut07em  ut07ey       ut07fm  ut07fy  ut07gh        ut07h  \
# 0     0020100  11:November  2014.0       7:July  2014.0    1.00      5:Other
# 1     0020600  11:November  2014.0        5:May  2014.0    0.50       1:Rain
# 2     0022000  12:December  2014.0     8:August  2014.0    0.25       1:Rain
# 3     0030100  9:September  2014.0        5:May  2014.0    0.25  2:Irigation
# 4     0030151   2:February  2015.0   10:October  2014.0    0.50       1:Rain
# ...       ...          ...     ...          ...     ...     ...          ...
# 2438  3211700     8:August  2014.0      4:April  2014.0     NaN       1:Rain
# 2439  3211751       6:June  2015.0      3:March  2015.0     NaN       1:Rain
# 2440  3212100      4:April  2014.0  11:November  2013.0     NaN       1:Rain
# 2441  3212600  9:September  2014.0       6:June  2014.0     NaN       1:Rain
# 2442  3213000     8:August  2014.0      4:April  2014.0     NaN       1:Rain
#
# ...

# %%
ut3_14_ft = ut3_14[['hhid14','ut3type','ut09sm','ut09sy','ut09t']]
ut3_14_ft.head()
# Out:
#     hhid14 ut3type    ut09sm  ut09sy      ut09t
# 0  0012200      C1       NaN     NaN        NaN
# 1  0012200      C4       NaN     NaN        NaN
# 2  0012200      C5       NaN     NaN        NaN
# 3  0012200      C3  8:August  2014.0  4000000.0
# 4  0012200      C2       NaN     NaN        NaN

# %%
ut2_07_ft.duplicated().sum()
# Out:
# 10

# %%
ut2_14_ft.duplicated().sum()
# Out:
# 0

# %%
ut2_07_ft = ut2_07_ft.rename(columns={'hhid07': 'id','ut07em':'ut07em_2007',
                                      'ut07ey':'ut07ey_2007','ut07fm':'ut07fm_2007',
                                     'ut07fy_2014':'ut07fy_2007','ut07gh':'ut07gh_2007',
                                      'ut07h':'ut07h_2007', 'ut07i':'ut07i_2007',
                                      'ut07jh':'ut07jh_2007','ut07lxx':'ut07lxx_2007',
                                      'ut07m':'ut07m_2007', 'ut07p':'ut07p_2007'})
ut2_14_ft = ut2_14_ft.rename(columns={'hhid14': 'id','ut07em':'ut07em_2014',
                                      'ut07ey':'ut07ey_2014','ut07fm':'ut07fm_2014',
                                     'ut07fy':'ut07fy_2014','ut07gh':'ut07gh_2014',
                                      'ut07h':'ut07h_2014', 'ut07i':'ut07i_2014',
                                      'ut07jh':'ut07jh_2014','ut07lxx':'ut07lxx_2014',
                                      'ut07m':'ut07m_2014', 'ut07p':'ut07p_2014'})

# %%
ut2_merge = pd.merge(ut2_07_ft, ut2_14_ft, on='id', how='outer')
ut2_merge
# Out:
#            id  ut07emth  ut07eyr  ut07fmth  ut07fyr  ut07gh_2007  ut07h_2007  \
# 0     0020100      10.0   2007.0       5.0   2007.0          1.0         1.0
# 1     0020100       4.0   2007.0      11.0   2006.0          1.0         1.0
# 2     0020300      10.0   2007.0       7.0   2007.0          NaN         1.0
# 3     0020300       5.0   2007.0       2.0   2007.0          NaN         1.0
# 4     0020400      12.0   2007.0       7.0   2007.0          NaN         5.0
# ...       ...       ...      ...       ...      ...          ...         ...
# 4826  3201552       NaN      NaN       NaN      NaN          NaN         NaN
# 4827  3211252       NaN      NaN       NaN      NaN          NaN         NaN
# 4828  3211352       NaN      NaN       NaN      NaN          NaN         NaN
# 4829  3211751       NaN      NaN       NaN      NaN          NaN         NaN
# 4830  3212100       NaN      NaN       NaN      NaN          NaN         NaN
#
# ...

# %% [markdown]
# Task:
# 1. Berapa rumah tangga yang 2007 tidak pakai irigasi, kemudian di 2014 memakai irigasi
# 2. Berapa rumah tangga yang 2014 tidak pakai irigasi, kemudian di 2007 memakai irigasi

# %%
# Task 1
non_irr_07 = ut2_merge[(ut2_merge['ut07h_2007'] != 2) & (ut2_merge['ut07h_2014'] == '2:Irigation')]
non_irr_07['ut07h_2007'].unique()
# Out:
# array([ 5.,  1.,  3.,  9., nan])

# %%
# Task 2
non_irr_14 = ut2_merge[(ut2_merge['ut07h_2014'] != '2:Irigation') & (ut2_merge['ut07h_2007'] == 2)]
non_irr_14['ut07h_2014'].unique()
# Out:
# [NaN, '5:Other', '1:Rain', '3:Well/pump', '9:Missing']
# Categories (5, object): ['1:Rain' < '2:Irigation' < '3:Well/pump' < '5:Other' < '9:Missing']

# %%
# Menghitung jumlah rumah tangga yang 2014 tidak pakai irigasi, kemudian di 2007 memakai irigasi
jmlh_2014 = non_irr_14['ut07h_2014'].notna().sum()
jmlh_2014
# Out:
# 216

# %%
# Menghitung jumlah rumah tangga yang 2007 tidak pakai irigasi, kemudian di 2014 memakai irigasi
jmlh_2007 = non_irr_07['ut07h_2007'].notna().sum()
jmlh_2007
# Out:
# 227

# %%
ut2_clean
# Out:
# Empty DataFrame
# Columns: [id, ut07emth, ut07eyr, ut07fmth, ut07fyr, ut07gh_2007, ut07h_2007, ut07i_2007, ut07jh_2007, ut07lxx_2007, ut07m_2007, ut07p_2007, ut07em_2014, ut07ey_2014, ut07fm_2014, ut07fy_2014, ut07gh_2014, ut07h_2014, ut07i_2014, ut07jh_2014, ut07lxx_2014, ut07m_2014, ut07p_2014]
# Index: []
#
# [0 rows x 23 columns]

# %%
ut3_07_ft = ut3_07_ft.rename(columns={'hhid07': 'id'})
ut3_14_ft = ut3_14_ft.rename(columns={'hhid14': 'id'})

# %%
ut3_merge = pd.merge(ut3_07_ft, ut3_14_ft, on=['id', 'ut3type'], how='outer')
ut3_merge
# Out:
#            id ut3type  ut09sm_x  ut09sy_x    ut09t_x     ut09sm_y ut09sy_y  \
# 0     0012200      C1       NaN       NaN        NaN          NaN      NaN
# 1     0012200      C2       NaN       NaN        NaN          NaN      NaN
# 2     0012200      C3       NaN       NaN        NaN     8:August   2014.0
# 3     0012200      C4       7.0    2007.0  1500000.0          NaN      NaN
# 4     0012200      C5       NaN       NaN        NaN          NaN      NaN
# ...       ...     ...       ...       ...        ...          ...      ...
# 8635  3212600      C4       NaN       NaN        NaN          NaN      NaN
# 8636  3212600      C1       NaN       NaN        NaN          NaN      NaN
# 8637  3212600      C2       NaN       NaN        NaN          NaN      NaN
# 8638  3212600      C3       NaN       NaN        NaN  9:September   2014.0
# 8639  3212600      C5       NaN       NaN        NaN          NaN      NaN
#
#         ut09t_y
# 0           NaN
# 1           NaN
# ...

# %%
ut2_merge.to_csv('ut2_merge.csv')

# %%
ut3_merge.to_csv('ut3_merge.csv')
